# %%
import sys
import os

from itertools import chain, combinations
from collections import defaultdict
from optparse import OptionParser

def subsets(arr):
    """ Returns non empty subsets of arr"""
    return chain(*[combinations(arr, i + 1) for i, a in enumerate(arr)])

def returnItemsWithMinSupport(itemSet, transactionList, minSupport, freqSet):
        """calculates the support for items in the itemSet and returns a subset
       of the itemSet each of whose elements satisfies the minimum support"""
        _itemSet = set()
        localSet = defaultdict(int)

        for item in itemSet:
                for transaction in transactionList:
                        if item.issubset(transaction):
                                freqSet[item] += 1
                                localSet[item] += 1

        for item, count in localSet.items():
                support = float(count)/len(transactionList)

                if support >= minSupport:
                        _itemSet.add(item)

        return _itemSet

def joinSet(itemSet, length):
        """Join a set with itself and returns the n-element itemsets"""
        return set([i.union(j) for i in itemSet for j in itemSet if len(i.union(j)) == length])

def getItemSetTransactionList(data_iterator):
    transactionList = list()
    itemSet = set()
    for record in data_iterator:
        transaction = frozenset(record)
        transactionList.append(transaction)
        for item in transaction:
            itemSet.add(frozenset([item]))              # Generate 1-itemSets
    return itemSet, transactionList

def runApriori(data_iter, minSupport, minConfidence):
    """
    run the apriori algorithm. data_iter is a record iterator
    Return both:
     - items (tuple, support)
     - rules ((pretuple, posttuple), confidence)
    """
    itemSet, transactionList = getItemSetTransactionList(data_iter)

    freqSet = defaultdict(int)
    largeSet = dict()
    # Global dictionary which stores (key=n-itemSets,value=support)
    # which satisfy minSupport

    assocRules = dict()
    # Dictionary which stores Association Rules

    oneCSet = returnItemsWithMinSupport(itemSet,
                                        transactionList,
                                        minSupport,
                                        freqSet)
    currentLSet = oneCSet
    k = 2
    while(currentLSet != set([])):
        largeSet[k-1] = currentLSet
        currentLSet = joinSet(currentLSet, k)
        currentCSet = returnItemsWithMinSupport(currentLSet,
                                                transactionList,
                                                minSupport,
                                                freqSet)
        currentLSet = currentCSet
        k = k + 1
        
        def getSupport(item):
            """local function which Returns the support of an item"""
            return float(freqSet[item])/len(transactionList)

    toRetItems = []
    for key, value in largeSet.items():
        toRetItems.extend([(tuple(item), getSupport(item))
                           for item in value])

    toRetRules = []
    for key, value in largeSet.items()[1:]:
        for item in value:
            _subsets = map(frozenset, [x for x in subsets(item)])
            for element in _subsets:
                remain = item.difference(element)
                if len(remain) > 0:
                    confidence = getSupport(item)/getSupport(element)
                    if confidence >= minConfidence:
                        toRetRules.append(((tuple(element), tuple(remain)),
                                           confidence))
    return toRetItems, toRetRules



def printResults(items, rules):
    
    """prints the generated itemsets sorted by support and the confidence rules sorted by confidence"""
    for item, support in sorted(items, key=lambda support:support[1]):#lambda (item, support): support):  #lambda support:support[1]):
        print ("item: %s , %.3f" % (str(item), support))
    print ("\n------------------------ RULES:")
    for rule, confidence in sorted(rules, key=lambda  confidence: confidence[1]):
        pre, post = rule
        print ("Rule: %s ==> %s , %.3f" % (str(pre), str(post), confidence))
        
def dataFromFile(fname):
        """Function which reads from the file and yields a generator"""
        
        file_iter = open(fname, 'rU')
        for line in file_iter:
                line = line.strip().rstrip(',')                         # Remove trailing comma
                record = frozenset(line.split(','))
                yield record
                print(record)

if __name__ == "__main__":
    optparser = OptionParser()
    optparser.add_option('-f', '--inputFile',
                         dest='input',
                         help='filename containing csv',
                         default=None)
    optparser.add_option('-s', '--minSupport',
                         dest='minS',
                         help='minimum support value',
                         default=0.15,
                         type='float')
    optparser.add_option('-c', '--minConfidence',
                         dest='minC',
                         help='minimum confidence value',
                         default=0.6,
                         type='float')

    (options, args) = optparser.parse_args()

    file_location = os.path.join(os.path.expanduser('./dataset'),'INTEGRATED-DATASET.csv')
    inFile = dataFromFile(file_location)
    minSupport = options.minS
    minConfidence = options.minC

    items, rules = runApriori(inFile, minSupport, minConfidence)

    printResults(items, rules)
    
    

# optparser = OptionParser()
#    optparser.add_option('-f', '--inputFile',
#                         dest='input',
#                         help='filename containing csv',
#                         default=None)
#    optparser.add_option('-s', '--minSupport',
#                         dest='minS',
#                         help='minimum support value',
#                         default=0.15,
#                         type='float')
#    optparser.add_option('-c', '--minConfidence',
#                         dest='minC',
#                         help='minimum confidence value',
#                         default=0.6,
#                         type='float')
#
#    (options, args) = optparser.parse_args()
#
#    inFile = None
#    if options.input is None:
#            inFile = sys.stdin
#    elif options.input is not None:
#   file_location = os.path.join(os.path.expanduser('~'),'Documents','Apriori-master','data2.csv')
#            inFile = dataFromFile(options.input)
#    else:
#            print ('No dataset filename specified, system with exit\n')
#            sys.exit('System will exit')
#
#        minSupport = options.minS
#    minConfidence = options.minC
#
#    items, rules = runApriori(inFile, minSupport, minConfidence)

#    printResults(items, rules)
# Out:
# /root/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:116: DeprecationWarning: 'U' mode is deprecated
# frozenset({'11204', 'Brooklyn', 'LBE'})
# frozenset({'MBE', '11411', 'Cambria Heights', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Yorktown Heights', '10598', 'BLACK'})
# frozenset({'MBE', 'Long Beach', 'BLACK', '11561'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11235'})
# frozenset({'10010', 'MBE', 'ASIAN', 'New York', 'WBE'})
# frozenset({'10026', 'MBE', 'ASIAN', 'New York'})
# frozenset({'10026', 'MBE', 'New York', 'BLACK'})
# frozenset({'MBE', '10034', 'HISPANIC', 'New York'})
# frozenset({'MBE', 'Staten Island', '10303', 'BLACK', 'WBE'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York'})
# frozenset({'MBE', '10034', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'10013', 'MBE', 'ASIAN', 'New York', 'WBE'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11434'})
# frozenset({'10022', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'Staten Island', '10304', 'BLACK'})
# frozenset({'MBE', '10454', 'Bronx', 'BLACK'})
# frozenset({'10801', 'NON-MINORITY', 'New Rochelle', 'WBE'})
# frozenset({'NON-MINORITY', 'Staten Island', '10301', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10006', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11239', 'BLACK'})
# frozenset({'MBE', 'HISPANIC', 'Lincoln Park', '7035'})
# frozenset({'MBE', '10027', 'New York', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', 'Staten Island', '10310', 'WBE'})
# frozenset({'10013', 'MBE', 'ASIAN', 'New York'})
# frozenset({'NON-MINORITY', '7010', 'Cliffside Park', 'WBE'})
# frozenset({'MBE', '10456', 'Bronx', 'BLACK', 'WBE'})
# frozenset({'New York', 'LBE', '10003'})
# frozenset({'MBE', 'Staten Island', 'HISPANIC', '10303'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'MBE', 'New York', 'BLACK', '11435'})
# frozenset({'Ozone Park', '11417', 'WBE'})
# frozenset({'11559', 'NON-MINORITY', 'Lawrence', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'LBE', '11230', 'ASIAN'})
# frozenset({'MBE', 'HISPANIC', 'Lynbrook', '11563'})
# frozenset({'MBE', 'Newark', '7104', 'BLACK'})
# frozenset({'College Point', 'NON-MINORITY', '11356', 'WBE'})
# frozenset({'MBE', '7922', 'ASIAN', 'Berkeley Heights'})
# frozenset({'MBE', '10040', 'WBE', 'New York', 'LBE', 'HISPANIC'})
# frozenset({'MBE', 'ASIAN', '11370', 'East Elmhurst'})
# frozenset({'11106', 'Astoria', 'LBE'})
# frozenset({'MBE', '10001', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'MBE', 'LBE', 'Bronx', 'BLACK', '10457'})
# frozenset({'11420', 'MBE', 'South Ozone Park', 'BLACK', 'WBE'})
# frozenset({'MBE', 'ASIAN', '10920', 'Congers'})
# frozenset({'MBE', '10456', 'Bronx', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11219'})
# frozenset({'Bayside', 'MBE', 'ASIAN', '11360'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10462'})
# frozenset({'MBE', 'LBE', 'Bronx', '10470', 'BLACK'})
# frozenset({'11803', 'MBE', 'ASIAN', 'Plainview'})
# frozenset({'NON-MINORITY', 'Bronx', '10461', 'WBE'})
# frozenset({'11726', 'NON-MINORITY', 'Copiague', 'WBE'})
# frozenset({'Bellingham', 'NON-MINORITY', '98229', 'WBE'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11435'})
# frozenset({'11375', 'NON-MINORITY', 'Forest Hills', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10012', 'WBE'})
# frozenset({'MBE', 'Bronx', '10463', 'WBE', 'BLACK', 'LBE'})
# frozenset({'MBE', '11706', 'Bay Shore', 'BLACK'})
# frozenset({'Montclair', 'NON-MINORITY', '7042', 'WBE'})
# frozenset({'NON-MINORITY', '11101', 'Elmhurst', 'WBE'})
# frozenset({'11801', 'MBE', 'Hicksville', 'ASIAN'})
# frozenset({'MBE', '7675', 'Westwood', 'HISPANIC'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York'})
# frozenset({'11764', 'LBE', 'Miller Place'})
# frozenset({'MBE', 'ASIAN', '11753', 'Jericho'})
# frozenset({'New York', 'NON-MINORITY', '10107', 'WBE'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11432'})
# frozenset({'MBE', '11367', 'ASIAN', 'Flushing'})
# frozenset({'MBE', '10019', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Richmond Hill', 'ASIAN', '11418', 'WBE'})
# frozenset({'MBE', '11550', 'BLACK', 'Hempstead'})
# frozenset({'10465', 'MBE', 'Bronx', 'HISPANIC', 'WBE'})
# frozenset({'10520', 'MBE', 'Croton-on-Hudson', 'HISPANIC', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10010'})
# frozenset({'NON-MINORITY', 'Bronx', '10461', 'WBE'})
# frozenset({'NON-MINORITY', '11501', 'Mineola', 'WBE'})
# frozenset({'Mount Vernon', 'MBE', 'ASIAN', '10550'})
# frozenset({'10573', 'MBE', 'Port Chester', 'HISPANIC'})
# frozenset({'11566', 'NON-MINORITY', 'Merrick', 'WBE'})
# frozenset({'NON-MINORITY', 'Long Island City', '11101', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11208'})
# frozenset({'Floral Park', 'MBE', 'ASIAN', '11001'})
# frozenset({'New York', 'NON-MINORITY', '10017', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10017', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'New York', '10016'})
# frozenset({'MBE', 'Bronx', '10469', 'BLACK'})
# frozenset({'MBE', 'ASIAN', 'New York', '10011'})
# frozenset({'10466', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'MBE', 'ASIAN', '11554', 'East Meadow'})
# frozenset({'Ocean Township', 'NON-MINORITY', '7712', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'Bronx', '10454'})
# frozenset({'Flushing', 'NON-MINORITY', '11366', 'WBE'})
# frozenset({'7004', 'NON-MINORITY', 'Fairfield', 'WBE'})
# frozenset({'MBE', 'ASIAN', '10016', 'New York', 'WBE'})
# frozenset({'MBE', 'Richmond Hill', 'ASIAN', '11418'})
# frozenset({'MBE', 'Brooklyn', '11216', 'BLACK'})
# frozenset({'MBE', '10013', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10454', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'New York', '10010'})
# frozenset({'NON-MINORITY', '7642', 'Hillsdale', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11238', 'BLACK', 'WBE'})
# frozenset({'Bayside', 'MBE', 'LBE', 'ASIAN', '11361'})
# frozenset({'10456', 'MBE', 'Bronx', 'HISPANIC'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York'})
# frozenset({'NON-MINORITY', '10523', 'Elmsford', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11220'})
# frozenset({'10514', 'NON-MINORITY', 'Chappaqua', 'WBE'})
# frozenset({'MBE', 'ASIAN', '11417', 'Ozone Park'})
# frozenset({'MBE', 'ASIAN', 'Jamaica', '11435'})
# frozenset({'MBE', 'Westbury', 'HISPANIC', '11590'})
# frozenset({'10174', 'MBE', 'ASIAN', 'New York'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10032'})
# frozenset({'New York', '10175', 'WBE'})
# frozenset({'MBE', '10128', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'11217', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'11225', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'11225', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'7003', 'MBE', 'Bloomfield', 'HISPANIC', 'WBE'})
# frozenset({'MBE', 'Bronx', '10463', 'HISPANIC'})
# frozenset({'8904', 'NON-MINORITY', 'Highland Park', 'WBE'})
# frozenset({'MBE', 'Astoria', 'HISPANIC', '11102', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11221', 'BLACK'})
# frozenset({'NON-MINORITY', 'South Salem', '10590', 'WBE'})
# frozenset({'10467', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'MBE', '10940', 'LBE', 'HISPANIC', 'Middletown'})
# frozenset({'MBE', 'Brooklyn', '11212', 'BLACK'})
# frozenset({'MBE', 'ASIAN', 'N Plainfield', '7060'})
# frozenset({'MBE', '7069', 'Watchung', 'BLACK'})
# frozenset({'MBE', '11355', 'ASIAN', 'Flushing'})
# frozenset({'NON-MINORITY', '10474', 'Bronx', 'WBE'})
# frozenset({'MBE', 'Forest Hills', 'HISPANIC', '11375', 'WBE'})
# frozenset({'10467', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10021', 'WBE'})
# frozenset({'Whitestone', 'NON-MINORITY', '11357', 'WBE'})
# frozenset({'MBE', 'Plainfield', '7060', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10013', 'WBE'})
# frozenset({'11214', 'MBE', 'Brooklyn', 'LBE', 'ASIAN'})
# frozenset({'11206', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', 'LBE', 'HISPANIC', 'Jamaica', '11434'})
# frozenset({'NON-MINORITY', 'LIC', '11101', 'WBE'})
# frozenset({'MBE', '7010', 'HISPANIC', 'Cliffside Park', 'WBE'})
# frozenset({'NON-MINORITY', 'White Plains', '10604', 'WBE'})
# frozenset({'MBE', 'ASIAN', '11354', 'Flushing'})
# frozenset({'MBE', 'ASIAN', 'New York', '10016'})
# frozenset({'10314', 'NON-MINORITY', 'Staten Island', 'WBE'})
# frozenset({'Lindehurst', 'MBE', 'ASIAN', '11757'})
# frozenset({'MBE', 'ASIAN', '11753', 'Jericho'})
# frozenset({'NON-MINORITY', '11701', 'Amityville', 'WBE'})
# frozenset({'MBE', '11378', 'HISPANIC', 'Maspeth'})
# frozenset({'MBE', 'Brooklyn', '11234', 'BLACK', 'WBE'})
# frozenset({'MBE', 'New York', 'BLACK', '10030'})
# frozenset({'MBE', '11746', 'Huntington Station', 'BLACK', 'WBE'})
# frozenset({'MBE', 'NATIVE AMERICAN', '14092', 'Lewiston', 'WBE'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10462'})
# frozenset({'MBE', '11691', 'Far Rockaway', 'BLACK'})
# frozenset({'MBE', 'St. Albans', '11412', 'BLACK'})
# frozenset({'NON-MINORITY', '11230', 'Brooklyn', 'WBE'})
# frozenset({'11021', 'MBE', 'Great Neck', 'HISPANIC'})
# frozenset({'MBE', 'ASIAN', 'Albertson', '11507'})
# frozenset({'MBE', '10118', 'New York', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10017', 'WBE'})
# frozenset({'MBE', 'St. Albans', '11412', 'BLACK'})
# frozenset({'Staten Island', 'MBE', 'ASIAN', '10302', 'WBE'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'Flemington', '8822', 'NON-MINORITY', 'WBE'})
# frozenset({'11203', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'MBE', 'Alpine', 'ASIAN', '7620', 'WBE'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York', 'WBE'})
# frozenset({'MBE', 'HISPANIC', '11550', 'Hempstead'})
# frozenset({'MBE', 'Mount Vernon', 'HISPANIC', '10552'})
# frozenset({'MBE', 'Queens Village', '11427', 'BLACK'})
# frozenset({'11206', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '11373', 'HISPANIC', 'Elmhurst'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11232'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11231'})
# frozenset({'NON-MINORITY', 'Staten Island', '10306', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10013', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10021', 'WBE'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11205', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11234', 'BLACK', 'WBE'})
# frozenset({'MBE', 'ASIAN', '7080', 'South Plainfield'})
# frozenset({'Huntington', 'NON-MINORITY', '11743', 'WBE'})
# frozenset({'11377', 'MBE', 'LBE', 'ASIAN', 'Woodside'})
# frozenset({'MBE', '10001', 'New York', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11221', 'BLACK'})
# frozenset({'10176', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'Hackensack', 'BLACK', '7601'})
# frozenset({'MBE', '10462', 'ASIAN', 'Bronx'})
# frozenset({'Yonkers', 'MBE', '10703', 'BLACK'})
# frozenset({'10467', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'New Hyde Park', 'MBE', '11040', 'HISPANIC'})
# frozenset({'MBE', 'ASIAN', '11370', 'East Elmhurst'})
# frozenset({'MBE', 'New York', 'BLACK', '10030'})
# frozenset({'MBE', 'Long Island City', 'HISPANIC', '11101'})
# frozenset({'10302', 'NON-MINORITY', 'Staten Island', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', '10001', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11233'})
# frozenset({'10165', 'MBE', 'ASIAN', 'New York'})
# frozenset({'MBE', 'Dayton', 'ASIAN', '8810'})
# frozenset({'Springfield Gardens', 'MBE', 'ASIAN', '11413'})
# frozenset({'MBE', '10018', 'HISPANIC', 'New York'})
# frozenset({'MBE', 'ASIAN', 'Hillsborough', '8844'})
# frozenset({'MBE', 'Brooklyn', '11226', 'BLACK'})
# frozenset({'MBE', '8837', 'HISPANIC', 'Edison', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10033'})
# frozenset({'MBE', '11422', 'BLACK', 'Rosedale'})
# frozenset({'11204', 'MBE', 'Brooklyn', 'LBE', 'ASIAN'})
# frozenset({'MBE', '11101', 'ASIAN', 'Long Island City'})
# frozenset({'MBE', '10029', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', '8003', 'Cherry Hill', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', 'Long Island City', '11101', 'WBE'})
# frozenset({'LBE', 'Jamaica', '11435'})
# frozenset({'11201', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', 'Woodbridge', 'ASIAN', '7095'})
# frozenset({'NON-MINORITY', 'Brooklyn', '11205', 'WBE'})
# frozenset({'10466', 'MBE', 'Bronx', 'BLACK', 'WBE'})
# frozenset({'11106', 'MBE', 'Long Island City', 'HISPANIC'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10011'})
# frozenset({'MBE', 'Brooklyn', 'LBE', '11236', 'ASIAN'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11432'})
# frozenset({'MBE', '11691', 'Far Rockaway', 'BLACK'})
# frozenset({'10013', 'MBE', 'ASIAN', 'New York'})
# frozenset({'MBE', 'ASIAN', 'New York', '10011'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11434'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10010'})
# frozenset({'MBE', 'Union', 'HISPANIC', '7083', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11208', 'BLACK'})
# frozenset({'MBE', '10454', 'Bronx', 'BLACK'})
# frozenset({'MBE', '7950', 'ASIAN', 'Morris Plains', 'WBE'})
# frozenset({'MBE', 'Jackson Heights', 'HISPANIC', '11372'})
# frozenset({'MBE', 'ASIAN', 'New York', '10011', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'New York', '10016'})
# frozenset({'MBE', 'South Nyack', 'BLACK', '10960'})
# frozenset({'Totowa', '7511', 'NON-MINORITY', 'WBE'})
# frozenset({'NON-MINORITY', 'Westfield', '7090', 'WBE'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10003', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11211'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10469'})
# frozenset({'MBE', '10470', 'Bronx', 'BLACK'})
# frozenset({'NON-MINORITY', 'Jamaica', '11430', 'WBE'})
# frozenset({'Summit', 'NON-MINORITY', '7901', 'WBE'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10460', 'WBE'})
# frozenset({'10022', 'MBE', 'ASIAN', 'New York', 'WBE'})
# frozenset({'11565', 'MBE', 'Malverne', 'BLACK'})
# frozenset({'MBE', 'LBE', '10012', 'ASIAN', 'New York'})
# frozenset({'MBE', 'Briarwood', 'BLACK', '11435'})
# frozenset({'MBE', '11509', 'HISPANIC', 'Atlantic Beach'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11205'})
# frozenset({'MBE', '10454', 'Bronx', 'BLACK'})
# frozenset({'10941', 'NON-MINORITY', 'Middletown', 'WBE'})
# frozenset({'MBE', 'New York', 'BLACK', '10030'})
# frozenset({'10024', 'MBE', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11226'})
# frozenset({'Huntington', '11746', 'LBE'})
# frozenset({'MBE', 'Brooklyn', '11236', 'BLACK'})
# frozenset({'MBE', '10038', 'ASIAN', 'New York'})
# frozenset({'NON-MINORITY', '7020', 'Edgewater', 'WBE'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', '10280', 'New York', 'BLACK'})
# frozenset({'11415', 'MBE', 'BLACK', 'Kew Gardens'})
# frozenset({'MBE', '10457', 'Bronx', 'BLACK'})
# frozenset({'MBE', 'ASIAN', 'Cranbury', '8512'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10011'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11435'})
# frozenset({'Huntington', 'NON-MINORITY', '11743', 'WBE'})
# frozenset({'MBE', 'ASIAN', '11417', 'Ozone Park'})
# frozenset({'New York', 'NON-MINORITY', '10025', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11233', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', '11218', 'Brooklyn', 'WBE'})
# frozenset({'11210', 'MBE', 'Brooklyn', 'LBE', 'BLACK'})
# frozenset({'Harrison', 'NON-MINORITY', '10532', 'WBE'})
# frozenset({'NON-MINORITY', '11746', 'Dix Hills', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10012', 'WBE'})
# frozenset({'MBE', '10019', 'HISPANIC', 'New York'})
# frozenset({'MBE', 'ASIAN', '11716', 'Bohemia'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11232'})
# frozenset({'NON-MINORITY', '11558', 'Island Park', 'WBE'})
# frozenset({'MBE', 'Bellerose Village', '11001', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Coram', '11727', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', 'Tarrytown', '10591', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11224', 'BLACK'})
# frozenset({'7650', 'NON-MINORITY', 'Palisades Park', 'WBE'})
# frozenset({'MBE', '10036', 'New York', 'BLACK'})
# frozenset({'MBE', '10019', 'New York', 'BLACK'})
# frozenset({'MBE', '10018', 'HISPANIC', 'New York'})
# frozenset({'7601', 'NON-MINORITY', 'Hackensack', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10032', 'WBE'})
# frozenset({'11757', 'NON-MINORITY', 'Lindenhurst', 'WBE'})
# frozenset({'MBE', '10012', 'HISPANIC', 'New York'})
# frozenset({'NON-MINORITY', '6880', 'Westport', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10004', 'WBE'})
# frozenset({'NON-MINORITY', 'Nyack', '10960', 'WBE'})
# frozenset({'10007', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', '10031', 'New York', 'BLACK', 'WBE'})
# frozenset({'7087', 'MBE', 'HISPANIC', 'Union City'})
# frozenset({'MBE', 'Hackensack', 'HISPANIC', '7601'})
# frozenset({'MBE', 'ASIAN', '11354', 'Flushing'})
# frozenset({'N/A', '11791', 'Syosset', 'WBE'})
# frozenset({'New York', '10013', 'WBE'})
# frozenset({'MBE', 'Bronx', '10453', 'BLACK', 'WBE'})
# frozenset({'MBE', '10023', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11432'})
# frozenset({'New York', 'NON-MINORITY', '10013', 'WBE'})
# frozenset({'MBE', '10279', 'ASIAN', 'New York'})
# frozenset({'11106', 'MBE', 'ASIAN', 'Long Island City'})
# frozenset({'MBE', '10018', 'New York', 'WBE'})
# frozenset({'11385', 'MBE', 'HISPANIC', 'Ridgewood'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'NON-MINORITY', 'Staten Island', '10310', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'LBE', '11238', 'ASIAN'})
# frozenset({'New York', 'NON-MINORITY', '10002', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10004', 'WBE'})
# frozenset({'MBE', '10001', 'New York', 'BLACK'})
# frozenset({'Elmont', 'MBE', '11003', 'BLACK'})
# frozenset({'MBE', 'Ossining', 'BLACK', '10562'})
# frozenset({'MBE', '10019', 'New York', 'BLACK'})
# frozenset({'11501', 'MBE', 'ASIAN', 'Mineola'})
# frozenset({'11581', 'NON-MINORITY', 'Valley Stream', 'WBE'})
# frozenset({'MBE', '10035', 'New York', 'BLACK'})
# frozenset({'Fort Salonga', 'NON-MINORITY', '11768', 'WBE'})
# frozenset({'NON-MINORITY', '11222', 'Brooklyn', 'WBE'})
# frozenset({'New Hyde Park', 'MBE', '11040', 'LBE', 'ASIAN'})
# frozenset({'MBE', '7070', 'ASIAN', 'Rutherford', 'WBE'})
# frozenset({'11209', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '11556', 'Uniondale', 'BLACK'})
# frozenset({'Middle Village', 'LBE', '11379'})
# frozenset({'Jersey City', 'MBE', 'ASIAN', '7310', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'MBE', '11422', 'BLACK', 'Rosedale'})
# frozenset({'South Richmond Hill', 'MBE', '11419', 'BLACK'})
# frozenset({'11224', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11236', 'BLACK'})
# frozenset({'MBE', 'St. Albans', '11412', 'BLACK'})
# frozenset({'MBE', 'New York', 'BLACK', '10030'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11206'})
# frozenset({'Kinnelon', 'NON-MINORITY', '7405', 'WBE'})
# frozenset({'7601', 'NON-MINORITY', 'Hackensack', 'WBE'})
# frozenset({'Deer Park', 'MBE', '11729', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', 'Bronx', '10454', 'WBE'})
# frozenset({'11201', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10036'})
# frozenset({'MBE', 'ASIAN', '11417', 'Ozone Park'})
# frozenset({'New York', 'NON-MINORITY', '10005', 'WBE'})
# frozenset({'MBE', '7728', 'Freehold', 'BLACK', 'WBE'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'NON-MINORITY', '11804', 'Old Bethpage', 'WBE'})
# frozenset({'MBE', '10456', 'Bronx', 'BLACK', 'WBE'})
# frozenset({'LBE', '8857', 'Old Bridge'})
# frozenset({'Bayside', 'MBE', 'ASIAN', '11361'})
# frozenset({'MBE', '11355', 'ASIAN', 'Flushing'})
# frozenset({'NON-MINORITY', 'Manasquan', '8736', 'WBE'})
# frozenset({'MBE', '10001', 'HISPANIC', 'New York'})
# frozenset({'11229', 'NON-MINORITY', 'LBE', 'Brooklyn', 'WBE'})
# frozenset({'10465', 'MBE', 'Bronx', 'HISPANIC'})
# frozenset({'11206', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '10035', 'New York', 'BLACK'})
# frozenset({'10022', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'11106', 'MBE', 'Astoria', 'HISPANIC'})
# frozenset({'New York', 'NON-MINORITY', '10004', 'WBE'})
# frozenset({'11377', 'NON-MINORITY', 'Woodside', 'WBE'})
# frozenset({'MBE', 'HISPANIC', '11694', 'Rockaway Park'})
# frozenset({'10466', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'MBE', '10004', 'New York', 'BLACK'})
# frozenset({'MBE', 'Long Beach', 'ASIAN', '11561', 'WBE'})
# frozenset({'MBE', 'ASIAN', '10120', 'New York'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11434'})
# frozenset({'10030', 'MBE', 'New York', 'BLACK', 'WBE'})
# frozenset({'Tenafly', 'MBE', 'BLACK', '7670'})
# frozenset({'11210', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'10451', 'MBE', 'Bronx', 'HISPANIC'})
# frozenset({'New York', 'NON-MINORITY', '10009', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'New York', '10016'})
# frozenset({'MBE', 'Brooklyn', 'LBE', 'HISPANIC', '11231'})
# frozenset({'Mt. Vernon', 'MBE', '10553', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', 'LBE', '11216', 'BLACK'})
# frozenset({'Yonkers', 'MBE', 'BLACK', '10701'})
# frozenset({'MBE', '10025', 'HISPANIC', 'New York'})
# frozenset({'MBE', '10457', 'Bronx', 'BLACK'})
# frozenset({'10312', 'NON-MINORITY', 'Staten Island', 'WBE'})
# frozenset({'10314', 'NON-MINORITY', 'Staten Island', 'WBE'})
# frozenset({'Staten Island', '10302', 'LBE'})
# frozenset({'10594', 'NON-MINORITY', 'Thornwood', 'WBE'})
# frozenset({'MBE', '10168', 'HISPANIC', 'New York'})
# frozenset({'MBE', 'Richmond Hill', 'BLACK', '11419'})
# frozenset({'MBE', 'Brooklyn', '11218', 'HISPANIC', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10075', 'WBE'})
# frozenset({'MBE', '11411', 'BLACK', 'Cambria Heights'})
# frozenset({'New York', 'NON-MINORITY', '10005', 'WBE'})
# frozenset({'11722', 'MBE', 'HISPANIC', 'Central Islip'})
# frozenset({'10026', 'MBE', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11205', 'BLACK', 'WBE'})
# frozenset({'MBE', '10475', 'Bronx', 'BLACK'})
# frozenset({'MBE', '10018', 'New York', 'BLACK'})
# frozenset({'Staten Island', 'LBE', '10314'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11205'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10454', 'WBE'})
# frozenset({'MBE', '10550', 'HISPANIC', 'Mt. Vernon'})
# frozenset({'11433', 'MBE', 'HISPANIC', 'Jamaica'})
# frozenset({'MBE', '10004', 'New York', 'BLACK'})
# frozenset({'MBE', 'HISPANIC', 'Syosset', '11791'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10469'})
# frozenset({'MBE', 'Brooklyn', '11226', 'BLACK'})
# frozenset({'MBE', '10993', 'HISPANIC', 'West Haverstraw'})
# frozenset({'MBE', '10458', 'Bronx', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11216', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10012', 'WBE'})
# frozenset({'NON-MINORITY', 'Long Island City', '11101', 'WBE'})
# frozenset({'MBE', '11501', 'Mineola', 'BLACK'})
# frozenset({'7755', 'NON-MINORITY', 'Oakhurst', 'WBE'})
# frozenset({'MBE', '10029', 'HISPANIC', 'New York'})
# frozenset({'MBE', '10038', 'HISPANIC', 'New York'})
# frozenset({'MBE', 'ASIAN', '8812', 'Greenbrook', 'WBE'})
# frozenset({'MBE', 'Mount Vernon', '10553', 'BLACK'})
# frozenset({'10456', 'MBE', 'Bronx', 'HISPANIC'})
# frozenset({'11106', 'MBE', 'Astoria', 'LBE', 'ASIAN'})
# frozenset({'Roslyn', 'MBE', 'LBE', 'HISPANIC', '11576'})
# frozenset({'MBE', '7071', 'BLACK', 'Lyndhurst'})
# frozenset({'MBE', '10031', 'New York', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10013', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11226', 'BLACK'})
# frozenset({'10467', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'7645', 'NON-MINORITY', 'Montvale', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10023', 'WBE'})
# frozenset({'10920', 'NON-MINORITY', 'Congers', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11207'})
# frozenset({'MBE', '10034', 'HISPANIC', 'New York'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'Yonkers', 'MBE', '10703', 'BLACK'})
# frozenset({'10708', 'NON-MINORITY', 'Bronxville', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'11795', 'MBE', 'ASIAN', 'West Islip', 'WBE'})
# frozenset({'MBE', '11691', 'HISPANIC', 'Far Rockaway'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'BLACK', '11205'})
# frozenset({'River Edge', 'MBE', '7661', 'ASIAN'})
# frozenset({'MBE', '10037', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'7092', 'MBE', 'ASIAN', 'Mountainside'})
# frozenset({'MBE', 'Brooklyn', '11220', 'BLACK'})
# frozenset({'NON-MINORITY', '11215', 'Brooklyn', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10024', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10017', 'WBE'})
# frozenset({'MBE', '11101', 'ASIAN', 'Long Island City', 'WBE'})
# frozenset({'10007', 'MBE', 'ASIAN', 'New York'})
# frozenset({'NON-MINORITY', 'Brooklyn', '11208', 'WBE'})
# frozenset({'11385', 'NON-MINORITY', 'Glendale', 'WBE'})
# frozenset({'NON-MINORITY', '11218', 'Brooklyn', 'WBE'})
# frozenset({'NON-MINORITY', '11234', 'Brooklyn', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'New York', '10004'})
# frozenset({'MBE', 'Bronx', '10455', 'HISPANIC'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'10475', 'LBE', 'Bronx'})
# frozenset({'Hazlet', 'NON-MINORITY', '7730', 'WBE'})
# frozenset({'MBE', 'Hartsdale', 'BLACK', '10530'})
# frozenset({'Staten Island', 'MBE', 'ASIAN', '10306'})
# frozenset({'MBE', 'Brooklyn', '11226', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11226', 'BLACK'})
# frozenset({'MBE', 'ASIAN', 'Hoboken', '7030'})
# frozenset({'MBE', 'ASIAN', '11417', 'Ozone Park'})
# frozenset({'LBE', 'Maspeth', '11378'})
# frozenset({'MBE', 'HISPANIC', '11417', 'Ozone Park'})
# frozenset({'Staten Island', 'MBE', '10310', 'ASIAN'})
# frozenset({'Bayside', 'NON-MINORITY', '11361', 'WBE'})
# frozenset({'Monsey', 'MBE', 'HISPANIC', '10952'})
# frozenset({'Springfield Gardens', 'MBE', 'HISPANIC', '11413'})
# frozenset({'10467', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10013', 'WBE'})
# frozenset({'Lattingtown', 'NON-MINORITY', '11560', 'WBE'})
# frozenset({'11377', 'MBE', 'HISPANIC', 'Woodside'})
# frozenset({'10467', 'MBE', 'Bronx', 'HISPANIC', 'WBE'})
# frozenset({'MBE', '11719', 'Brookhaven', 'BLACK', 'WBE'})
# frozenset({'Marion', 'NON-MINORITY', '2738', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11232', 'HISPANIC'})
# frozenset({'MBE', 'Westbury', 'HISPANIC', '11590'})
# frozenset({'10007', 'MBE', 'ASIAN', 'New York'})
# frozenset({'NON-MINORITY', 'Staten Island', '10304', 'WBE'})
# frozenset({'MBE', '10470', 'Bronx', 'BLACK'})
# frozenset({'Howard Beach', 'MBE', 'HISPANIC', '11414', 'WBE'})
# frozenset({'MBE', '10018', 'New York', 'BLACK'})
# frozenset({'MBE', '7631', 'BLACK', 'Englewood'})
# frozenset({'MBE', 'Brooklyn', '11216', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Freeport', '11520', 'BLACK'})
# frozenset({'11722', 'MBE', 'HISPANIC', 'Central Islip'})
# frozenset({'MBE', '10003', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10460'})
# frozenset({'MBE', 'Laurelton', 'BLACK', '11413'})
# frozenset({'MBE', '11101', 'Long Island City'})
# frozenset({'MBE', 'HISPANIC', '11354', 'Flushing'})
# frozenset({'MBE', 'Mount Vernon', '10550', 'BLACK'})
# frozenset({'11210', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11208'})
# frozenset({'10026', 'MBE', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', '8558', 'ASIAN', 'Skillman'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'MBE', '10001', 'HISPANIC', 'New York'})
# frozenset({'Flushing', 'NON-MINORITY', '11355', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11237'})
# frozenset({'Mt. Vernon', 'MBE', '10553', 'BLACK', 'WBE'})
# frozenset({'MBE', '10001', 'HISPANIC', 'New York'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'Bergenfield', 'NON-MINORITY', '7621', 'WBE'})
# frozenset({'7608', 'MBE', 'HISPANIC', 'Teterboro', 'WBE'})
# frozenset({'NON-MINORITY', 'Booton', '7005', 'WBE'})
# frozenset({'LBE', 'Maspeth', '11378'})
# frozenset({'MBE', 'Newark', '7107', 'BLACK'})
# frozenset({'MBE', '10038', 'New York', 'BLACK'})
# frozenset({'Farmingdale', 'MBE', 'ASIAN', '11735', 'WBE'})
# frozenset({'Poughquag', 'MBE', 'ASIAN', '12570'})
# frozenset({'MBE', '8540', 'Princeton', 'BLACK'})
# frozenset({'MBE', 'New York', 'BLACK', '10010'})
# frozenset({'MBE', '7033', 'ASIAN', 'Kenilworth'})
# frozenset({'10314', 'MBE', 'Staten Island', 'HISPANIC'})
# frozenset({'Vero Beach', 'MBE', '32963', 'HISPANIC', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11205', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10038', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'New York', '10021'})
# frozenset({'MBE', 'Brooklyn', '11236', 'BLACK'})
# frozenset({'11206', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'NON-MINORITY', '11501', 'Mineola', 'WBE'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', '10029', 'New York', 'BLACK'})
# frozenset({'New York', 'LBE', '10016'})
# frozenset({'NON-MINORITY', 'LBE', 'Maspeth', '11378', 'WBE'})
# frozenset({'Harrison', 'NON-MINORITY', '10528', 'WBE'})
# frozenset({'MBE', 'Medord', 'ASIAN', '11763', 'WBE'})
# frozenset({'MBE', '10001', 'New York', 'BLACK'})
# frozenset({'11747', 'NON-MINORITY', 'Melville', 'WBE'})
# frozenset({'MBE', '6801', 'BLACK', 'Bethel'})
# frozenset({'MBE', 'Long Island City', 'HISPANIC', '11101'})
# frozenset({'Massapequa', 'LBE', '11758'})
# frozenset({'MBE', 'Newark', '7107', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10011', 'WBE'})
# frozenset({'MBE', '11743', 'Huntington', 'BLACK'})
# frozenset({'Baldwin', 'NON-MINORITY', '11510', 'WBE'})
# frozenset({'MBE', '11411', 'BLACK', 'Cambria Heights'})
# frozenset({'11375', 'NON-MINORITY', 'Forest Hills', 'WBE'})
# frozenset({'MBE', '11374', 'Rego Park', 'BLACK'})
# frozenset({'MBE', 'Mount Vernon', '10552', 'BLACK'})
# frozenset({'Garden City', '11530', 'NON-MINORITY', 'WBE'})
# frozenset({'Cedarhurst', 'NON-MINORITY', '11516', 'WBE'})
# frozenset({'10119', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'Elmont', 'MBE', '11003', 'BLACK', 'WBE'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'10566', 'MBE', 'HISPANIC', 'Peekskill'})
# frozenset({'10566', 'MBE', 'HISPANIC', 'Peekskill'})
# frozenset({'11201', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'Carle Place', 'NON-MINORITY', '11514', 'WBE'})
# frozenset({'MBE', 'Hackensack', 'HISPANIC', '7601', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10010'})
# frozenset({'11106', 'NON-MINORITY', 'Long Island City', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11217', 'HISPANIC'})
# frozenset({'MBE', '11743', 'Huntington', 'BLACK'})
# frozenset({'MBE', 'ASIAN', '11354', 'Flushing'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10005'})
# frozenset({'MBE', '11566', 'ASIAN', 'Merrick', 'WBE'})
# frozenset({'MBE', '11566', 'ASIAN', 'Merrick', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11226', 'BLACK'})
# frozenset({'NON-MINORITY', '11235', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '10005', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10461'})
# frozenset({'Millstone Township', 'NON-MINORITY', '8535', 'WBE'})
# frozenset({'Yorktown Heights', 'NON-MINORITY', '10598', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10011', 'WBE'})
# frozenset({'10465', 'LBE', 'Bronx'})
# frozenset({'MBE', '10001', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'MBE', 'Tuckahoe', 'HISPANIC', '10707'})
# frozenset({'10465', 'LBE', 'Bronx'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11211', 'BLACK'})
# frozenset({'MBE', '10562', 'Ossining', 'HISPANIC', 'WBE'})
# frozenset({'MBE', '10601', 'White Plains', 'BLACK', 'WBE'})
# frozenset({'MBE', '10005', 'New York', 'BLACK'})
# frozenset({'MBE', 'Hawthorne', '10532', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10013', 'WBE'})
# frozenset({'MBE', 'HISPANIC', '11420', 'South Ozone Park'})
# frozenset({'11756', 'Levittown', 'NON-MINORITY', 'WBE'})
# frozenset({'10451', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'MBE', 'Tinton Falls', 'ASIAN', '7724'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', '11563', 'Lynbrook', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11237'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10005'})
# frozenset({'MBE', '11436', 'Jamaica', 'BLACK'})
# frozenset({'10013', 'MBE', 'ASIAN', 'New York'})
# frozenset({'MBE', 'Brooklyn', '11216', 'BLACK'})
# frozenset({'11746', 'MBE', 'Dix Hills', 'ASIAN', 'WBE'})
# frozenset({'MBE', 'St. Albans', '11412', 'BLACK'})
# frozenset({'Hazlet', 'NON-MINORITY', '7730', 'WBE'})
# frozenset({'MBE', 'White Plains', 'BLACK', '10601'})
# frozenset({'11225', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10035', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11217', 'BLACK'})
# frozenset({'MBE', '11580', 'Valley Stream', 'BLACK'})
# frozenset({'Yonkers', 'MBE', '10701', 'BLACK', 'WBE'})
# frozenset({'MBE', '10801', 'New Rochelle', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', '8836', 'Martinsville', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10025', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10017', 'WBE'})
# frozenset({'MBE', '7020', 'Edgewater', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11229'})
# frozenset({'7018', 'MBE', 'BLACK', 'East Orange'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11205'})
# frozenset({'MBE', 'ASIAN', '10510', 'Briarcliff Manor'})
# frozenset({'MBE', 'Long Island City', 'HISPANIC', '11101'})
# frozenset({'New York', 'NON-MINORITY', '10003', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11212', 'WBE'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'New York', '10036'})
# frozenset({'Rahway', 'NON-MINORITY', '7065', 'WBE'})
# frozenset({'10007', 'MBE', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11434'})
# frozenset({'MBE', '10038', 'ASIAN', 'New York'})
# frozenset({'10026', 'MBE', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Long Island City', 'HISPANIC', '11101'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', '10462', 'Bronx', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10012', 'WBE'})
# frozenset({'MBE', '10128', 'HISPANIC', 'New York'})
# frozenset({'MBE', 'Long Island City', 'HISPANIC', '11101'})
# frozenset({'MBE', 'Brooklyn', '11213', 'BLACK'})
# frozenset({'NON-MINORITY', '11241', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '11704', 'West Babylon', 'BLACK'})
# frozenset({'MBE', '10018', 'HISPANIC', 'New York'})
# frozenset({'NON-MINORITY', 'Long Island City', '11101', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10017', 'WBE'})
# frozenset({'NON-MINORITY', '7652', 'Paramus', 'WBE'})
# frozenset({'MBE', '7677', 'ASIAN', 'Woodcliff Lake', 'WBE'})
# frozenset({'11225', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'10007', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', '11101', 'LBE', 'Long Island City', 'BLACK'})
# frozenset({'Elmont', 'MBE', '11003', 'HISPANIC', 'WBE'})
# frozenset({'7047', 'MBE', 'ASIAN', 'N. Bergen'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10005'})
# frozenset({'NON-MINORITY', '11704', 'West Babylon', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10165', 'WBE'})
# frozenset({'10022', 'MBE', 'ASIAN', 'New York'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', '10006', 'New York', 'BLACK'})
# frozenset({'7932', 'MBE', 'Florham Park', 'BLACK', 'WBE'})
# frozenset({'MBE', '10475', 'Bronx', 'BLACK'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'MBE', '11373', 'HISPANIC', 'Elmhurst', 'WBE'})
# frozenset({'10467', 'MBE', 'ASIAN', 'Bronx'})
# frozenset({'11201', 'Brooklyn', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'Bronx', '10469'})
# frozenset({'Ardsley', 'MBE', '10502', 'ASIAN', 'WBE'})
# frozenset({'MBE', '10032', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', 'North Bellmore', 'HISPANIC', '11710', 'WBE'})
# frozenset({'10466', 'LBE', 'Bronx'})
# frozenset({'MBE', '10473', 'Bronx', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11213', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11236', 'BLACK'})
# frozenset({'MBE', 'New York', 'BLACK', '10037'})
# frozenset({'10007', 'MBE', 'HISPANIC', 'New York'})
# frozenset({'10467', 'MBE', 'Bronx', 'HISPANIC'})
# frozenset({'Melville', 'MBE', '11747', 'BLACK', 'WBE'})
# frozenset({'MBE', 'ASIAN', '11354', 'Flushing'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11216'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10030'})
# frozenset({'MBE', '10128', 'New York', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11222', 'BLACK', 'WBE'})
# frozenset({'11201', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '10956', 'HISPANIC', 'New City', 'WBE'})
# frozenset({'NON-MINORITY', '11429', 'Queens Village', 'WBE'})
# frozenset({'8830', 'MBE', 'ASIAN', 'Iselin'})
# frozenset({'11433', 'MBE', 'Jamaica', 'BLACK'})
# frozenset({'11428', 'MBE', 'Queens Village', 'ASIAN'})
# frozenset({'MBE', '10002', 'ASIAN', 'New York', 'WBE'})
# frozenset({'MBE', '10031', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Bronx', '10460', 'BLACK'})
# frozenset({'MBE', '11575', 'HISPANIC', 'Roosevelt'})
# frozenset({'11050', 'MBE', 'ASIAN', 'Port Washington'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11207'})
# frozenset({'New York', 'NON-MINORITY', '10032', 'WBE'})
# frozenset({'MBE', 'Bronx', '10458', 'HISPANIC'})
# frozenset({'MBE', 'Bronx', 'BLACK', '10452'})
# frozenset({'MBE', 'ASIAN', 'New York', '10010'})
# frozenset({'MBE', 'Mount Vernon', '10550', 'BLACK'})
# frozenset({'NON-MINORITY', 'Riverdale', '10471', 'WBE'})
# frozenset({'MBE', 'ASIAN', '11418', 'Richmond Hills'})
# frozenset({'11203', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'MBE', 'Hackensack', 'BLACK', '7601'})
# frozenset({'Bayside', 'MBE', 'ASIAN', '11361'})
# frozenset({'MBE', 'HISPANIC', '7022', 'Fairview'})
# frozenset({'MBE', 'ASIAN', '11354', 'Flushing'})
# frozenset({'MBE', '10001', 'HISPANIC', 'New York'})
# frozenset({'East Northport', 'NON-MINORITY', '11731', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11201'})
# frozenset({'MBE', 'Brooklyn', '11236', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11238', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10017', 'WBE'})
# frozenset({'11201', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '11101', 'Long Island City', 'BLACK'})
# frozenset({'NON-MINORITY', '11215', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '10027', 'New York', 'BLACK'})
# frozenset({'MBE', '11225', 'WBE', 'Brooklyn', 'BLACK', 'LBE'})
# frozenset({'Deer Park', 'NON-MINORITY', '11729', 'WBE'})
# frozenset({'10026', 'MBE', 'New York', 'BLACK', 'WBE'})
# frozenset({'MBE', '11716', 'Bohemia', 'BLACK'})
# frozenset({'Floral Park', 'MBE', 'LBE', 'ASIAN', '11004'})
# frozenset({'11210', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10454'})
# frozenset({'Staten Island', 'MBE', 'ASIAN', '10301'})
# frozenset({'MBE', '10475', 'Bronx', 'BLACK'})
# frozenset({'MBE', '10475', 'Bronx', 'BLACK'})
# frozenset({'MBE', '11101', 'Long Island City', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10024', 'WBE'})
# frozenset({'11223', 'MBE', 'Brooklyn', 'BLACK', 'WBE'})
# frozenset({'7092', 'MBE', 'ASIAN', 'Mountainside'})
# frozenset({'NON-MINORITY', 'Ossining', '10562', 'WBE'})
# frozenset({'NON-MINORITY', '6880', 'Westport', 'WBE'})
# frozenset({'MBE', 'Long Island City', 'HISPANIC', '11101', 'WBE'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', '11411', 'BLACK', 'Cambria Heights'})
# frozenset({'Somerset', 'MBE', '8873', 'BLACK'})
# frozenset({'NON-MINORITY', '7041', 'Millburn', 'WBE'})
# frozenset({'Baldwin', 'MBE', '11510', 'BLACK'})
# frozenset({'10466', 'MBE', 'Bronx', 'BLACK', 'WBE'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', '11422', 'BLACK', 'Rosedale'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'MBE', '11378', 'HISPANIC', 'Maspeth'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'MBE', '10280', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'Whitestone', 'NON-MINORITY', '11357', 'WBE'})
# frozenset({'MBE', 'Yorktown Heights', '10598', 'BLACK', 'WBE'})
# frozenset({'10022', 'MBE', 'New York', 'BLACK'})
# frozenset({'Corona', 'MBE', 'ASIAN', '11368'})
# frozenset({'11741', 'NON-MINORITY', 'Holbrook', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10003', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11205', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10005', 'WBE'})
# frozenset({'11201', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11233', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', '11804', 'Old Bethpage', 'WBE'})
# frozenset({'New York', '10001', 'N/A', 'WBE'})
# frozenset({'10007', 'MBE', 'ASIAN', 'New York'})
# frozenset({'MBE', 'Astoria', 'HISPANIC', '11105', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10037'})
# frozenset({'East Northport', 'NON-MINORITY', '11731', 'WBE'})
# frozenset({'MBE', 'LBE', '10025', 'ASIAN', 'New York'})
# frozenset({'MBE', '10018', 'New York', 'BLACK'})
# frozenset({'11435', 'NON-MINORITY', 'Briarwood', 'WBE'})
# frozenset({'MBE', '10023', 'ASIAN', 'New York'})
# frozenset({'10121', 'MBE', 'ASIAN', 'New York'})
# frozenset({'MBE', 'Freeport', '11520', 'BLACK', 'WBE'})
# frozenset({'10465', 'NON-MINORITY', 'Bronx', 'WBE'})
# frozenset({'MBE', '11422', 'BLACK', 'Rosedale'})
# frozenset({'Closter', 'NON-MINORITY', '7624', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10004', 'WBE'})
# frozenset({'10466', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11207'})
# frozenset({'Staten Island', 'LBE', '10308'})
# frozenset({'7657', 'MBE', 'ASIAN', 'Ridgefield'})
# frozenset({'10566', 'MBE', 'ASIAN', 'Peekskill'})
# frozenset({'Morristown', 'MBE', 'HISPANIC', '7960', 'WBE'})
# frozenset({'NON-MINORITY', 'Lake Success', '11042', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'Bronx', '10461'})
# frozenset({'MBE', '10461', 'Bronx', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'NON-MINORITY', '11211', 'Brooklyn', 'WBE'})
# frozenset({'West Hempstead', 'MBE', '11552', 'HISPANIC', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'11203', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'MBE', 'ASIAN', '10012', 'New York', 'WBE'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York', 'WBE'})
# frozenset({'11201', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'11217', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '7086', 'HISPANIC', 'Weehawken'})
# frozenset({'6825', 'NON-MINORITY', 'Fairfield', 'WBE'})
# frozenset({'MBE', 'NON-MINORITY', 'Scarsdale', '10583', 'WBE'})
# frozenset({'Yonkers', 'MBE', '10701', 'BLACK', 'WBE'})
# frozenset({'MBE', '11374', 'Rego Park', 'HISPANIC', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11206', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', 'Long Island City', '11101', 'WBE'})
# frozenset({'7606', 'NON-MINORITY', 'South Hackensack', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'Long Island City', '11102'})
# frozenset({'MBE', 'ASIAN', 'Jackson Heights', '11372'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', 'Arverne', '11692', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10021', 'WBE'})
# frozenset({'11385', 'MBE', 'HISPANIC', 'Ridgewood'})
# frozenset({'MBE', 'ASIAN', '11417', 'Ozone Park'})
# frozenset({'Nesconset', 'NON-MINORITY', '11767', 'WBE'})
# frozenset({'NON-MINORITY', 'Roslyn', '11576', 'WBE'})
# frozenset({'MBE', '11101', 'Long Island City', 'BLACK'})
# frozenset({'MBE', '10001', 'HISPANIC', 'New York'})
# frozenset({'MBE', '10018', 'HISPANIC', 'New York'})
# frozenset({'MBE', 'Westbury', '11590', 'BLACK'})
# frozenset({'Springfield Gardens', 'MBE', 'BLACK', '11413'})
# frozenset({'MBE', '11691', 'Far Rockaway', 'BLACK'})
# frozenset({'MBE', '10023', 'New York', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10024', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10036'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11216'})
# frozenset({'MBE', 'Albany', 'ASIAN', '12205', 'WBE'})
# frozenset({'MBE', '10019', 'HISPANIC', 'New York'})
# frozenset({'10314', 'NON-MINORITY', 'Staten Island', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11234', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Queens Village', '11429', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11221', 'BLACK'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10460'})
# frozenset({'MBE', 'Brooklyn', '11205', 'BLACK', 'WBE'})
# frozenset({'MBE', '11374', 'ASIAN', 'Rego Park'})
# frozenset({'MBE', 'Bronx', '10469', 'BLACK'})
# frozenset({'MBE', 'HISPANIC', '11550', 'Hempstead'})
# frozenset({'Corona', 'MBE', '11368', 'BLACK'})
# frozenset({'10467', 'MBE', 'Bronx', 'HISPANIC'})
# frozenset({'Brooklyn', 'LBE', '11206'})
# frozenset({'MBE', 'Brooklyn', 'LBE', '11210'})
# frozenset({'NON-MINORITY', '11234', 'Brooklyn', 'WBE'})
# frozenset({'MBE', 'Jackson Heights', 'HISPANIC', '11372'})
# frozenset({'Staten Island', 'LBE', '10314'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11222'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10032'})
# frozenset({'MBE', 'Brooklyn', '11234', 'BLACK', 'WBE'})
# frozenset({'MBE', '10027', 'New York', 'BLACK'})
# frozenset({'MBE', 'ASIAN', '11563', 'Lynbrook'})
# frozenset({'MBE', 'LBE', 'Bronx', '10469', 'BLACK'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10454'})
# frozenset({'College Point', 'NON-MINORITY', '11356', 'WBE'})
# frozenset({'MBE', 'Branchberg', 'HISPANIC', '8876'})
# frozenset({'MBE', 'Brooklyn', 'BLACK', '11205'})
# frozenset({'MBE', '11575', 'Roosevelt', 'BLACK'})
# frozenset({'Wayne', 'MBE', 'HISPANIC', '7470', 'WBE'})
# frozenset({'Yonkers', 'MBE', '10710', 'BLACK'})
# frozenset({'7092', 'MBE', 'ASIAN', 'Mountainside'})
# frozenset({'MBE', 'ASIAN', '11550', 'Hempstead'})
# frozenset({'NON-MINORITY', 'Brooklyn', '11210', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11201', 'BLACK'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11434'})
# frozenset({'MBE', 'Richmond Hill', 'HISPANIC', '11418'})
# frozenset({'MBE', '10031', 'HISPANIC', 'New York'})
# frozenset({'New York', 'NON-MINORITY', '10028', 'WBE'})
# frozenset({'NON-MINORITY', '11218', 'Brooklyn', 'WBE'})
# frozenset({'11730', 'East Islip', 'NON-MINORITY', 'WBE'})
# frozenset({'11751', 'MBE', 'Islip', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10038', 'WBE'})
# frozenset({'Nesconset', 'NON-MINORITY', '11767', 'WBE'})
# frozenset({'MBE', 'ASIAN', '11354', 'Flushing'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'Astoria', 'NON-MINORITY', '11102', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10010'})
# frozenset({'MBE', '10031', 'New York', 'BLACK', 'WBE'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10021', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'Syosset', '11791'})
# frozenset({'10040', 'MBE', 'HISPANIC', 'New York'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'LBE', 'BLACK', '11205'})
# frozenset({'MBE', '10031', 'New York', 'BLACK'})
# frozenset({'MBE', '18301', 'East Stroudsburg', 'BLACK'})
# frozenset({'NON-MINORITY', '7728', 'Freehold', 'WBE'})
# frozenset({'MBE', 'Freeport', '11520', 'BLACK'})
# frozenset({'Flushing', 'NON-MINORITY', '11354', 'WBE'})
# frozenset({'East Northport', 'NON-MINORITY', '11731', 'WBE'})
# frozenset({'10013', 'MBE', 'ASIAN', 'New York', 'WBE'})
# frozenset({'MBE', 'Staten Island', '10303', 'BLACK'})
# frozenset({'10022', 'MBE', 'HISPANIC', 'New York'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11201', 'WBE'})
# frozenset({'10022', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'11756', 'MBE', 'Levittown', 'HISPANIC'})
# frozenset({'NON-MINORITY', 'Bronx', '10461', 'WBE'})
# frozenset({'Peeksville', 'MBE', '10566', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11211', 'HISPANIC', 'WBE'})
# frozenset({'10301', 'MBE', 'Staten Island', 'HISPANIC', 'WBE'})
# frozenset({'Yonkers', 'MBE', 'BLACK', '10701'})
# frozenset({'MBE', 'Richmond Hill', 'HISPANIC', '11418'})
# frozenset({'Farmingdale', 'MBE', 'HISPANIC', '7727'})
# frozenset({'MBE', 'Brooklyn', '11208', 'BLACK'})
# frozenset({'MBE', 'ASIAN', '10009', 'New York'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11226'})
# frozenset({'College Point', 'MBE', '11356', 'HISPANIC'})
# frozenset({'Jersey City', 'MBE', 'ASIAN', '7307'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', '10033', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'11372', 'MBE', 'Jackson Heights', 'HISPANIC', 'WBE'})
# frozenset({'7002', 'NON-MINORITY', 'Bayonne', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'West Orange', '7052'})
# frozenset({'MBE', '10038', 'ASIAN', 'New York'})
# frozenset({'MBE', 'Astoria', 'HISPANIC', '11105'})
# frozenset({'NON-MINORITY', '11553', 'Uniondale', 'WBE'})
# frozenset({'MBE', '10122', 'ASIAN', 'New York'})
# frozenset({'MBE', '10165', 'New York', 'BLACK'})
# frozenset({'NON-MINORITY', '11746', 'Dix Hills', 'WBE'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'New York', 'NON-MINORITY', '10028', 'WBE'})
# ...
# frozenset({'NON-MINORITY', 'Jamaica', '11430', 'WBE'})
# frozenset({'MBE', '10462', 'Bronx', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10023', 'WBE'})
# frozenset({'ASIAN', 'Saddle Brook', '7663', 'WBE'})
# frozenset({'NON-MINORITY', '11694', 'Belle Harbor', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'LBE', 'BLACK', '11205'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11208'})
# frozenset({'Yorktown Heights', 'NON-MINORITY', '10598', 'WBE'})
# frozenset({'10451', 'MBE', 'LBE', 'Bronx', 'BLACK'})
# frozenset({'MBE', 'Linwood', 'ASIAN', '8221'})
# frozenset({'MBE', '10591', 'ASIAN', 'Sleepy Hollow', 'WBE'})
# frozenset({'11721', 'MBE', 'HISPANIC', 'Centerport', 'WBE'})
# frozenset({'11747', 'NON-MINORITY', 'Melville', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10004', 'WBE'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'Staten Island', 'LBE', '10304'})
# frozenset({'MBE', '10018', 'New York', 'BLACK'})
# frozenset({'11428', 'MBE', 'Queens Village', 'ASIAN'})
# frozenset({'NON-MINORITY', '11746', 'Huntington Station', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11206'})
# frozenset({'MBE', '10018', 'New York', 'BLACK'})
# frozenset({'10466', 'MBE', 'Bronx', 'HISPANIC', 'WBE'})
# frozenset({'Farmingdale', 'NON-MINORITY', '11735', 'WBE'})
# frozenset({'Flushing', 'NON-MINORITY', '11358', 'WBE'})
# frozenset({'NON-MINORITY', '11234', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '10005', 'New York', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'11021', 'NON-MINORITY', 'Great Neck', 'WBE'})
# frozenset({'MBE', '10001', 'New York', 'BLACK'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'Rosedale', '11422', 'BLACK', 'WBE'})
# frozenset({'11242', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'11225', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'MBE', '11423', 'Hollis', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11216', 'BLACK'})
# frozenset({'10522', 'NON-MINORITY', 'Dobbs Ferry', 'WBE'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11230', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10025', 'WBE'})
# frozenset({'11203', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'10514', 'NON-MINORITY', 'Chappaqua', 'WBE'})
# frozenset({'Stamford', 'NON-MINORITY', '6902', 'WBE'})
# frozenset({'MBE', 'Glen Head', '11545', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11216', 'BLACK', 'WBE'})
# frozenset({'10458', 'MBE', 'ASIAN', 'Bronx'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', 'ASIAN', '11370', 'East Elmhurst'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'MBE', '11550', 'WBE', 'BLACK', 'Hempstead', 'LBE'})
# frozenset({'MBE', 'Brooklyn', '11204', 'BLACK'})
# frozenset({'MBE', '11378', 'Maspeth', 'WBE', 'LBE', 'HISPANIC'})
# frozenset({'Bowie', 'MBE', '20720', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', '11746', 'Huntington Station', 'WBE'})
# frozenset({'MBE', '11101', 'Long Island City', 'BLACK'})
# frozenset({'MBE', '11421', 'Woodhaven', 'BLACK'})
# frozenset({'MBE', 'New York', 'BLACK', '10033'})
# frozenset({'Valhalla', 'NON-MINORITY', '10595', 'WBE'})
# frozenset({'MBE', '10032', 'New York', 'WBE'})
# frozenset({'7513', 'MBE', 'HISPANIC', 'Paterson'})
# frozenset({'College Point', 'MBE', '11356', 'HISPANIC'})
# frozenset({'NON-MINORITY', 'Springfield', '7081', 'WBE'})
# frozenset({'NON-MINORITY', '11216', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '10038', 'New York', 'BLACK'})
# frozenset({'MBE', '7747', 'HISPANIC', 'Matawan'})
# frozenset({'Newark', 'NON-MINORITY', '7114', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'Hamilton Township', '8638'})
# frozenset({'11021', 'NON-MINORITY', 'Great Neck', 'WBE'})
# frozenset({'MBE', 'Long Island City', 'HISPANIC', '11101'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'10465', 'MBE', 'Bronx', 'HISPANIC', 'WBE'})
# frozenset({'MBE', '10025', 'HISPANIC', 'New York'})
# frozenset({'New York', 'NON-MINORITY', '10021', 'WBE'})
# frozenset({'MBE', '11373', 'ASIAN', 'Elmhurst'})
# frozenset({'MBE', 'ASIAN', '10016', 'New York', 'WBE'})
# frozenset({'NON-MINORITY', '10956', 'New City', 'WBE'})
# frozenset({'10022', 'MBE', 'HISPANIC', 'New York'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'10543', 'MBE', 'BLACK', 'Mamaroneck'})
# frozenset({'MBE', 'Arverne', '11692', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10004', 'WBE'})
# frozenset({'MBE', 'Montville', 'HISPANIC', '7045'})
# frozenset({'New York', 'NON-MINORITY', '10028', 'WBE'})
# frozenset({'11201', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10017', 'WBE'})
# frozenset({'Westbury', 'NON-MINORITY', '11590', 'WBE'})
# frozenset({'11225', 'MBE', 'Brooklyn', 'HISPANIC'})
# frozenset({'10007', 'MBE', 'New York', 'BLACK'})
# frozenset({'10451', 'MBE', 'Bronx', 'BLACK'})
# frozenset({'MBE', 'St. Albans', '11412', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11236', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11218'})
# frozenset({'MBE', 'Brooklyn', '11234', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'ASIAN', '11218'})
# frozenset({'MBE', 'Brooklyn', '11230', 'BLACK', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10019', 'WBE'})
# frozenset({'NON-MINORITY', '12534', 'Hudson', 'WBE'})
# frozenset({'7876', 'NON-MINORITY', 'Succasunna', 'WBE'})
# frozenset({'MBE', '10038', 'New York', 'BLACK'})
# frozenset({'NON-MINORITY', 'Brooklyn', '11231', 'WBE'})
# frozenset({'Scarsdale', 'NON-MINORITY', '10583', 'WBE'})
# frozenset({'MBE', 'Laurelton', 'BLACK', '11413'})
# frozenset({'11223', 'MBE', 'Brooklyn', 'ASIAN'})
# frozenset({'MBE', '11373', 'ASIAN', 'Elmhurst'})
# frozenset({'10467', 'MBE', 'Bronx', 'BLACK', 'WBE'})
# frozenset({'MBE', '10462', 'Bronx', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', 'Staten Island', '10309', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'New York', '10010'})
# frozenset({'MBE', '10014', 'HISPANIC', 'New York'})
# frozenset({'MBE', 'N/A', 'Hollis', '11423'})
# frozenset({'New York', 'NON-MINORITY', '10036', 'WBE'})
# frozenset({'NON-MINORITY', '11971', 'Southold', 'WBE'})
# frozenset({'MBE', '11746', 'LBE', 'BLACK', 'Huntington Station'})
# frozenset({'10039', 'MBE', 'LBE', 'ASIAN', 'New York'})
# frozenset({'Yonkers', 'MBE', 'HISPANIC', '10710'})
# frozenset({'MBE', '11550', 'BLACK', 'Hempstead'})
# frozenset({'MBE', 'Richmond Hill', 'ASIAN', '11419'})
# frozenset({'11217', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'Yonkers', 'NON-MINORITY', '10710', 'WBE'})
# frozenset({'11377', 'MBE', 'ASIAN', 'Woodside'})
# frozenset({'MBE', 'ASIAN', 'Edison', '8820'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10014', 'WBE'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10036', 'WBE'})
# frozenset({'NON-MINORITY', 'North Babylon', '11704', 'WBE'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York', 'WBE'})
# frozenset({'MBE', '10018', 'New York', 'BLACK'})
# frozenset({'MBE', 'ASIAN', '6478', 'Oxford'})
# frozenset({'Brooklyn', 'LBE', '11234'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10010'})
# frozenset({'Staten Island', 'MBE', 'ASIAN', '10301'})
# frozenset({'10604', 'White Plains', 'WBE'})
# frozenset({'MBE', 'ASIAN', '10003', 'New York'})
# frozenset({'MBE', 'Bronx', 'BLACK', '10453'})
# frozenset({'MBE', '10034', 'New York', 'BLACK', 'WBE'})
# frozenset({'Mahwah', 'NON-MINORITY', '7430', 'WBE'})
# frozenset({'MBE', '11096', 'HISPANIC', 'Inwood', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10005', 'WBE'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'MBE', 'Brooklyn', '11233', 'BLACK'})
# frozenset({'MBE', '11423', 'Hollis', 'BLACK'})
# frozenset({'MBE', 'Bronx', 'BLACK', '10452'})
# frozenset({'MBE', '10038', 'ASIAN', 'New York'})
# frozenset({'10022', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'ASIAN', 'New York', '10017'})
# frozenset({'MBE', 'Bronx', '10469', 'BLACK'})
# frozenset({'MBE', 'Mount Vernon', '10550', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10011', 'WBE'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'11232', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'Springfield Gardens', 'MBE', '11413', 'BLACK', 'WBE'})
# frozenset({'MBE', 'ASIAN', '11358', 'Flushing'})
# frozenset({'New York', 'NON-MINORITY', '10003', 'WBE'})
# frozenset({'11377', 'MBE', 'ASIAN', 'Woodside'})
# frozenset({'Deer Park', 'NON-MINORITY', '11729', 'WBE'})
# frozenset({'MBE', 'Brooklyn', 'HISPANIC', '11206'})
# frozenset({'MBE', '10457', 'Bronx', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', 'LBE', '11235', 'ASIAN'})
# frozenset({'NON-MINORITY', '11215', 'Brooklyn', 'WBE'})
# frozenset({'10466', 'MBE', 'Bronx', 'BLACK', 'WBE'})
# frozenset({'MBE', '11520', 'BLACK', 'Hempstead'})
# frozenset({'MBE', '10006', 'ASIAN', 'New York'})
# frozenset({'MBE', '11422', 'BLACK', 'Rosedale'})
# frozenset({'MBE', '11358', 'HISPANIC', 'Flushing'})
# frozenset({'MBE', 'ASIAN', '8817', 'Edison'})
# frozenset({'MBE', 'Brooklyn', 'BLACK', '11205'})
# frozenset({'Rahway', 'MBE', '7065', 'BLACK'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'Springfield Gardens', 'MBE', 'BLACK', '11413'})
# frozenset({'MBE', 'Bronx', '10472', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11211', 'HISPANIC'})
# frozenset({'New York', 'NON-MINORITY', '10025', 'WBE'})
# frozenset({'LBE', 'Maspeth', '11378'})
# frozenset({'MBE', '10031', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'NON-MINORITY', '7031', 'North Arlington', 'WBE'})
# frozenset({'Saugerties', '12477', 'WBE'})
# frozenset({'11428', 'MBE', 'Queens Village', 'BLACK'})
# frozenset({'MBE', 'ASIAN', 'New York', '10017'})
# frozenset({'MBE', 'ASIAN', 'East Norwich', '11732'})
# frozenset({'MBE', 'Brooklyn', '11236', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'7003', 'MBE', 'Bloomfield', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10011', 'WBE'})
# frozenset({'11934', 'NON-MINORITY', 'Center Moriches', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'MBE', '10001', 'ASIAN', 'New York'})
# frozenset({'Yonkers', 'MBE', 'BLACK', '10701'})
# frozenset({'11203', 'MBE', 'Brooklyn', 'BLACK'})
# frozenset({'NON-MINORITY', 'Long Island City', '11101', 'WBE'})
# frozenset({'Staten Island', 'MBE', 'ASIAN', '10306', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11233', 'BLACK'})
# frozenset({'NON-MINORITY', 'Bronx', '10471', 'WBE'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10460'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10011', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10010'})
# frozenset({'10040', 'MBE', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'NON-MINORITY', 'Sunnyside', '11104', 'WBE'})
# frozenset({'MBE', '11374', 'Rego Park', 'BLACK', 'WBE'})
# frozenset({'MBE', '10280', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'MBE', '11435', 'Jamaica', 'BLACK', 'WBE'})
# frozenset({'MBE', 'Baltimore', '21207', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11201', 'BLACK'})
# frozenset({'MBE', 'Brooklyn', '11236', 'BLACK'})
# frozenset({'NON-MINORITY', '11230', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '8844', 'Hillsborough', 'BLACK'})
# frozenset({'MBE', '10001', 'New York', 'BLACK'})
# frozenset({'Floral Park', 'MBE', 'HISPANIC', '11001', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10001', 'WBE'})
# frozenset({'MBE', 'Laurelton', 'BLACK', '11413'})
# frozenset({'New York', 'NON-MINORITY', '10036', 'WBE'})
# frozenset({'NON-MINORITY', 'Staten Island', '10308', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'New York', '10011', 'WBE'})
# frozenset({'MBE', 'HISPANIC', 'Morganville', '7751', 'WBE'})
# frozenset({'10018', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11434'})
# frozenset({'MBE', 'ASIAN', '10004', 'New York', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10016', 'WBE'})
# frozenset({'MBE', '10012', 'HISPANIC', 'New York', 'WBE'})
# frozenset({'Hillside', 'MBE', '7205', 'HISPANIC', 'WBE'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10023', 'WBE'})
# frozenset({'MBE', '10128', 'New York', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10038', 'WBE'})
# frozenset({'MBE', 'Freeport', '11520', 'BLACK'})
# frozenset({'New York', 'ASIAN', '10013', 'WBE'})
# frozenset({'MBE', 'Bronx', '10453', 'BLACK', 'WBE'})
# frozenset({'MBE', '11419', 'ASIAN', 'South Richmond Hill'})
# frozenset({'South Richmond Hill', 'MBE', '11419', 'BLACK'})
# frozenset({'11020', 'NON-MINORITY', 'Great Neck', 'WBE'})
# frozenset({'Yonkers', 'NON-MINORITY', '10710', 'WBE'})
# frozenset({'MBE', 'Jamaica', 'BLACK', '11432'})
# frozenset({'NON-MINORITY', '11235', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '10018', 'New York', 'BLACK', 'WBE'})
# frozenset({'11787', 'NON-MINORITY', 'Smithtown', 'WBE'})
# frozenset({'MBE', '7666', 'Teaneck', 'BLACK'})
# frozenset({'MBE', 'ASIAN', '11354', 'Flushing'})
# frozenset({'MBE', 'ASIAN', 'Jackson Heights', '11370'})
# frozenset({'NON-MINORITY', '10994', 'West Nyack', 'WBE'})
# frozenset({'11797', 'NON-MINORITY', 'Woodbury', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11226', 'BLACK'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'MBE', 'St. Albans', '11412', 'BLACK'})
# frozenset({'MBE', 'Bronx', 'HISPANIC', '10462', 'WBE'})
# frozenset({'Astoria', 'LBE', '11103'})
# frozenset({'MBE', '10027', 'HISPANIC', 'New York'})
# frozenset({'NON-MINORITY', '11215', 'Brooklyn', 'WBE'})
# frozenset({'MBE', '11581', 'ASIAN', 'Valley Stream', 'WBE'})
# frozenset({'White Plains', 'MBE', 'HISPANIC', '10601'})
# frozenset({'NON-MINORITY', '14580', 'Webster', 'WBE'})
# frozenset({'7036', 'MBE', 'ASIAN', 'Linden'})
# frozenset({'MBE', 'ASIAN', '7644', 'Lodi'})
# frozenset({'MBE', 'Brooklyn', '11233', 'BLACK'})
# frozenset({'MBE', '10018', 'ASIAN', 'New York'})
# frozenset({'New York', 'NON-MINORITY', '10014', 'WBE'})
# frozenset({'7047', 'MBE', 'ASIAN', 'North Bergen'})
# frozenset({'7407', 'MBE', 'ASIAN', 'Elmwood Park'})
# frozenset({'NON-MINORITY', 'Washington', '20005', 'WBE'})
# frozenset({'New York', '10075', 'WBE'})
# frozenset({'MBE', 'St. Albans', '11412', 'BLACK', 'WBE'})
# frozenset({'Garden City', '11530', 'NON-MINORITY', 'WBE'})
# frozenset({'NON-MINORITY', 'LBE', 'Bronx', '10461', 'WBE'})
# frozenset({'MBE', 'Bronx', '10469', 'BLACK', 'WBE'})
# frozenset({'11201', 'NON-MINORITY', 'Brooklyn', 'WBE'})
# frozenset({'New York', 'NON-MINORITY', '10003', 'WBE'})
# frozenset({'MBE', '11411', 'ASIAN', 'Cambria Heights'})
# frozenset({'Fort Lee', 'MBE', 'ASIAN', '7024'})
# frozenset({'Fort Lee', 'MBE', 'ASIAN', '7024'})
# frozenset({'MBE', '10001', 'New York', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10025', 'WBE'})
# frozenset({'MBE', 'East Meadow', 'ASIAN', '11554', 'WBE'})
# frozenset({'MBE', 'Brooklyn', '11208', 'BLACK', 'WBE'})
# frozenset({'NON-MINORITY', 'Avon by the Sea', '7717', 'WBE'})
# frozenset({'MBE', 'LBE', 'ASIAN', '11417', 'Ozone Park'})
# frozenset({'10010', 'New York', 'NON-MINORITY', 'WBE'})
# frozenset({'7666', 'NON-MINORITY', 'Teaneck', 'WBE'})
# frozenset({'MBE', '10456', 'Bronx', 'BLACK', 'WBE'})
# frozenset({'MBE', '7514', 'Paterson', 'BLACK'})
# frozenset({'New York', 'NON-MINORITY', '10023', 'WBE'})
# frozenset({'MBE', 'ASIAN', '11580', 'Valley Stream'})
# frozenset({'MBE', 'Brooklyn', '11214', 'BLACK'})
# frozenset({'New York', 'LBE', '10016'})
# frozenset({'MBE', 'ASIAN', 'New York', '10002'})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f4497fd45f10> in <module>()
#     145     minConfidence = options.minC
#     146
# --> 147     items, rules = runApriori(inFile, minSupport, minConfidence)
#     148
#     149     printResults(items, rules)
#
# <ipython-input-1-f4497fd45f10> in runApriori(data_iter, minSupport, minConfidence)
#      87
#      88     toRetRules = []
# ---> 89     for key, value in largeSet.items()[1:]:
#      90         for item in value:
#      91             _subsets = map(frozenset, [x for x in subsets(item)])
#
# TypeError: 'dict_items' object is not subscriptable
